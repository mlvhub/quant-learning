# %% [markdown]
# # Coding Challenge

# %% [markdown]
# 1. Calculate and compare the Sharpe Ratio (assumption: rf == 0) for 30 large US stocks that currently form the Dow Jones Industrial Average Index ("Dow Jones") for the time period between April 2019 and June 2021.
#
# 2. Determine the best-performing stock and the worst-performing stock according to the Sharpe Ratio.

# %%
import pandas as pd
import numpy as np
import yfinance as yf
pd.options.display.float_format = '{:.6f}'.format

# %%
dow_jones = pd.read_csv("dow-jones.csv")
dow_jones
# Out:
#    Symbol                         Description      Category2  \
# 0     WBA         Walgreen Boots Alliance Inc  Common stocks
# 1       V                    Visa Inc Class A  Common stocks
# 2     CRM                  Salesforce.Com Inc  Common stocks
# 3     CVX                        Chevron Corp  Common stocks
# 4      PG                    Procter & Gamble  Common stocks
# 5      VZ          Verizon Communications Inc  Common stocks
# 6     WMT                  Walmart Stores Inc  Common stocks
# 7     UNH              Unitedhealth Group Inc  Common stocks
# 8     TRV             Travelers Companies Inc  Common stocks
# 9     MCD                      Mcdonalds Corp  Common stocks
# 10    MMM                                  3M  Common stocks
# 11    NKE                    Nike Inc Class B  Common stocks
# 12    MRK                      Merck & Co Inc  Common stocks
# 13   MSFT                      Microsoft Corp  Common stocks
# 14    JPM                JP Morgan Chase & Co  Common stocks
# 15     KO                           Coca-Cola  Common stocks
# 16    JNJ                   Johnson & Johnson  Common stocks
# 17     GS             Goldman Sachs Group Inc  Common stocks
# 18     HD                      Home Depot Inc  Common stocks
# 19    HON         Honeywell International Inc  Common stocks
# 20    IBM  International Business Machines Co  Common stocks
# 21   INTC              Intel Corporation Corp  Common stocks
# 22    DIS                         Walt Disney  Common stocks
# 23    CAT                     Caterpillar Inc  Common stocks
# 24   CSCO                   Cisco Systems Inc  Common stocks
# 25    AXP                    American Express  Common stocks
# 26     BA                              Boeing  Common stocks
# 27   AMGN                           Amgen Inc  Common stocks
# 28   AAPL                           Apple Inc  Common stocks
# 29    DOW                            Dow Inc.  Common stocks
#
#                GICS Sector          Market cap Market Cap Weight Index Weight  \
# 0         Consumer Staples     $27,884,739,901             0.27%        0.00%
# 1   Information Technology    $420,787,379,804             4.08%        0.00%
# 2   Information Technology    $187,440,000,000             1.82%        0.00%
# 3                   Energy    $294,619,273,279             2.86%        0.00%
# 4         Consumer Staples    $339,221,329,564             3.29%        0.00%
# 5   Communication Services    $156,949,625,356             1.52%        0.00%
# 6         Consumer Staples    $379,144,006,976             3.67%        0.00%
# 7              Health Care    $438,353,946,746             4.25%        0.00%
# 8               Financials     $38,030,967,246             0.37%        0.00%
# 9   Consumer Discretionary    $197,226,207,929             1.91%        0.00%
# 10             Industrials     $55,698,356,678             0.54%        0.00%
# 11  Consumer Discretionary    $188,713,200,000             1.83%        0.00%
# 12             Health Care    $264,597,492,835             2.56%        0.00%
# 13  Information Technology  $2,066,846,488,973            20.03%        0.00%
# 14              Financials    $373,335,206,420             3.62%        0.00%
# 15        Consumer Staples    $259,232,228,017             2.51%        0.00%
# 16             Health Care    $471,501,804,279             4.57%        0.00%
# 17              Financials    $105,095,298,447             1.02%        0.00%
# 18  Consumer Discretionary    $288,156,017,708             2.79%        0.00%
# 19             Industrials    $124,888,775,904             1.21%        0.00%
# 20  Information Technology    $111,909,619,229             1.08%        0.00%
# 21  Information Technology    $120,097,110,000             1.16%        0.00%
# 22  Communication Services    $175,062,936,563             1.70%        0.00%
# 23             Industrials    $113,306,854,326             1.10%        0.00%
# 24  Information Technology    $203,685,293,554             1.97%        0.00%
# 25              Financials    $121,104,161,489             1.17%        0.00%
# 26             Industrials    $118,577,142,351             1.15%        0.00%
# 27             Health Care    $124,469,861,078             1.21%        0.00%
# 28  Information Technology  $2,514,581,877,780            24.37%        0.00%
# 29               Materials     $36,567,616,820             0.35%        0.00%
#
#    Dividend yield Country   Action
# 0           5.82%     USA  Analyze
# 1           0.74%     USA  Analyze
# 2           0.00%     USA  Analyze
# 3           3.69%     USA  Analyze
# 4           2.52%     USA  Analyze
# 5           6.76%     USA  Analyze
# 6           1.59%     USA  Analyze
# 7           1.40%     USA  Analyze
# 8           2.25%     USA  Analyze
# 9           2.13%     USA  Analyze
# 10          5.80%     USA  Analyze
# 11          1.06%     USA  Analyze
# 12          2.70%     USA  Analyze
# 13          0.93%     USA  Analyze
# 14          3.12%     USA  Analyze
# 15          2.94%     USA  Analyze
# 16          2.96%     USA  Analyze
# 17          2.99%     USA  Analyze
# 18          2.72%     USA  Analyze
# 19          2.13%     USA  Analyze
# 20          5.25%     USA  Analyze
# 21          4.94%     USA  Analyze
# 22          0.00%     USA  Analyze
# 23          2.13%     USA  Analyze
# 24          3.02%     USA  Analyze
# 25          1.27%     USA  Analyze
# 26          0.00%     USA  Analyze
# 27          3.37%     USA  Analyze
# 28          0.58%     USA  Analyze
# 29          5.32%     USA  Analyze

# %%
symbols = dow_jones.Symbol.to_list()
symbols
# Out:
# ['WBA',
#  'V',
#  'CRM',
#  'CVX',
#  'PG',
#  'VZ',
#  'WMT',
#  'UNH',
#  'TRV',
#  'MCD',
#  'MMM',
#  'NKE',
#  'MRK',
#  'MSFT',
#  'JPM',
#  'KO',
#  'JNJ',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'DIS',
#  'CAT',
#  'CSCO',
#  'AXP',
#  'BA',
#  'AMGN',
#  'AAPL',
#  'DOW']

# %%
start = "2019-03-01"
end = "2021-06-30"

# %%
df = yf.download(symbols, start, end)
df
# Out:
# [*********************100%***********************]  30 of 30 completed
#             Adj Close                                                         \
#                  AAPL       AMGN        AXP         BA        CAT        CRM
# Date
# 2019-03-01  42.277161 167.981613 102.227798 430.299957 123.730705 164.529999
# 2019-03-04  42.489792 166.768936 102.321693 422.555695 124.522774 158.500000
# 2019-03-05  42.412468 165.925354 102.180870 420.045898 123.433678 156.970001
# 2019-03-06  42.168419 160.942856 102.302925 414.518463 121.354538 156.789993
# 2019-03-07  41.680336 159.457748 101.251534 412.662994 119.527435 155.600006
# ...               ...        ...        ...        ...        ...        ...
# 2021-06-23 132.151382 223.615570 161.346069 243.570007 204.533142 241.839996
# 2021-06-24 131.864731 225.713898 163.474442 250.570007 209.842819 243.770004
# 2021-06-25 131.568207 227.334503 164.679504 248.380005 206.944016 241.869995
# 2021-06-28 133.218872 227.484375 160.140991 239.960007 206.905762 244.570007
# 2021-06-29 134.750916 227.128448 159.625900 235.759995 205.786423 245.809998
#
#                                                       ...    Volume            \
#                 CSCO        CVX        DIS       DOW  ...       MRK      MSFT
# Date                                                  ...
# 2019-03-01 44.839622 100.917915 112.633492       NaN  ...  10624205  23501200
# 2019-03-04 44.621574 100.992355 112.949623       NaN  ...   8522755  26608000
# 2019-03-05 44.743664 101.959946 112.623611       NaN  ...   8698190  19538300
# 2019-03-06 45.066383 102.158424 113.463341       NaN  ...   8167169  17687000
# 2019-03-07 44.734959 100.843491 112.633492       NaN  ...  10925505  25339000
# ...              ...        ...        ...       ...  ...       ...       ...
# 2021-06-23 49.312153  98.215591 175.330002 57.212437  ...   9539100  19518700
# 2021-06-24 49.330845  99.019653 177.929993 57.176201  ...   8601900  21446900
# 2021-06-25 49.592548  99.167542 178.350006 57.339275  ...  50285200  25611100
# 2021-06-28 49.499084  96.108406 176.570007 56.985950  ...   8796200  19590000
# 2021-06-29 49.452351  95.895844 173.929993 57.058418  ...   7696600  19937800
#
#                                                                        \
#                  NKE        PG      TRV       UNH         V        VZ
# Date
# 2019-03-01   6314900   7733200  1360400   6921300   7016800  10942700
# 2019-03-04   7339500   6895300   907900   8646300   6979700  13674400
# 2019-03-05   4976300   6274600  1324200   6924500   9678600  15749500
# 2019-03-06   3198000   4622300   896700   4878700   8186400  13935500
# 2019-03-07   4321800   8408600  1141100   5033500   8761700  12644200
# ...              ...       ...      ...       ...       ...       ...
# 2021-06-23   4566000   5796000   649600   2942100   6814700  16524500
# 2021-06-24  11420500   6056700  1026900   3309100   4611500  15386200
# 2021-06-25  46285400  24504900  1239700  16928900   7825200  14540300
# 2021-06-28  13133300   6065400   873300   3193300   9301700  13754900
# 2021-06-29  10279900   5792300   701400   2458800  11897700  15313000
#
#
#                  WBA       WMT
# Date
# 2019-03-01  10298900  10352500
# 2019-03-04  10870500   7683800
# 2019-03-05  11956100   6119300
# 2019-03-06  15392500   4696600
# 2019-03-07   9695800   6126600
# ...              ...       ...
# 2021-06-23   3489600   6463500
# 2021-06-24   3876900   7814700
# 2021-06-25   4094500   9546900
# 2021-06-28   3869200   5183000
# 2021-06-29   4223600  11987500
#
# [588 rows x 180 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 588 entries, 2019-03-01 to 2021-06-29
# Columns: 180 entries, ('Adj Close', 'AAPL') to ('Volume', 'WMT')
# dtypes: float64(151), int64(29)
# memory usage: 831.5 KB

# %%
# TODO: figure out how to do the blow
#df["Returns"] = df.Close.pct_change()
#df

# %%
returns = np.log(df.Close / df.Close.shift()) # daily log returns
returns
# Out:
#                 AAPL      AMGN       AXP        BA       CAT       CRM  \
# Date
# 2019-03-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-03-04  0.005017 -0.007245  0.000918 -0.018161  0.006381 -0.037338
# 2019-03-05 -0.001821 -0.005071 -0.001377 -0.005957 -0.008784 -0.009700
# 2019-03-06 -0.005771 -0.030489  0.001194 -0.013246 -0.016988 -0.001147
# 2019-03-07 -0.011642 -0.009270 -0.010330 -0.004486 -0.015170 -0.007619
# ...              ...       ...       ...       ...       ...       ...
# 2021-06-23 -0.002092 -0.005014  0.009198 -0.000862  0.003092 -0.005238
# 2021-06-24 -0.002171  0.009340  0.013105  0.028334  0.025629  0.007949
# 2021-06-25 -0.002251  0.007154  0.007345 -0.008779 -0.013910 -0.007825
# 2021-06-28  0.012468  0.000659 -0.027947 -0.034488 -0.000185  0.011101
# 2021-06-29  0.011435 -0.001566 -0.003222 -0.017658 -0.005425  0.005057
#
#                 CSCO       CVX       DIS       DOW  ...       MRK      MSFT  \
# Date                                                ...
# 2019-03-01       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2019-03-04 -0.004875  0.000737  0.002803       NaN  ... -0.003435 -0.002402
# 2019-03-05  0.002733  0.009535 -0.002891       NaN  ...  0.004047 -0.005001
# 2019-03-06  0.007187  0.001945  0.007428       NaN  ... -0.011572  0.000448
# 2019-03-07 -0.007381 -0.012955 -0.007341       NaN  ... -0.003846 -0.012245
# ...              ...       ...       ...       ...  ...       ...       ...
# 2021-06-23 -0.009432 -0.001223  0.010492 -0.005527  ... -0.008039 -0.000904
# 2021-06-24  0.000379  0.008153  0.014720 -0.000634  ...  0.010267  0.005339
# 2021-06-25  0.005291  0.001492  0.002358  0.002848  ...  0.010940 -0.006282
# 2021-06-28 -0.001886 -0.031334 -0.010031 -0.006181  ... -0.004414  0.013865
# 2021-06-29 -0.000945 -0.002214 -0.015065  0.001271  ...  0.004543  0.009924
#
#                  NKE        PG       TRV       UNH         V        VZ  \
# Date
# 2019-03-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-03-04 -0.017593  0.004359 -0.006637 -0.042025 -0.010154 -0.012721
# 2019-03-05 -0.002338  0.002223  0.004078  0.022663 -0.000068 -0.002849
# 2019-03-06 -0.003635 -0.001616 -0.006730 -0.009823 -0.000947 -0.007158
# 2019-03-07  0.001526 -0.003848 -0.002355 -0.009963 -0.006652  0.011074
# ...              ...       ...       ...       ...       ...       ...
# 2021-06-23  0.004669 -0.001428 -0.002701 -0.007882 -0.005312 -0.005336
# 2021-06-24  0.003750  0.000677  0.013899  0.008333  0.006625  0.005336
# 2021-06-25  0.144372  0.014182  0.011601  0.015128  0.004561  0.000177
# 2021-06-28 -0.012977  0.002960 -0.015075 -0.008656 -0.013704 -0.003554
# 2021-06-29  0.023289 -0.006822  0.000468 -0.008405  0.007914 -0.006070
#
#                  WBA       WMT
# Date
# 2019-03-01       NaN       NaN
# 2019-03-04 -0.028476 -0.000817
# 2019-03-05 -0.020915  0.004995
# 2019-03-06 -0.036952 -0.000814
# 2019-03-07 -0.021673 -0.008278
# ...              ...       ...
# 2021-06-23  0.005970 -0.007839
# 2021-06-24  0.000384  0.006963
# 2021-06-25  0.001151  0.011763
# 2021-06-28  0.000958 -0.003109
# 2021-06-29 -0.004223 -0.005810
#
# [588 rows x 30 columns]

# %%
td_year = returns.count() / ((returns.index[-1] - returns.index[0]).days / 365.25)
td_year
# Out:
# AAPL   251.940952
# AMGN   251.940952
# AXP    251.940952
# BA     251.940952
# CAT    251.940952
# CRM    251.940952
# CSCO   251.940952
# CVX    251.940952
# DIS    251.940952
# DOW    246.361340
# GS     251.940952
# HD     251.940952
# HON    251.940952
# IBM    251.940952
# INTC   251.940952
# JNJ    251.940952
# JPM    251.940952
# KO     251.940952
# MCD    251.940952
# MMM    251.940952
# MRK    251.940952
# MSFT   251.940952
# NKE    251.940952
# PG     251.940952
# TRV    251.940952
# UNH    251.940952
# V      251.940952
# VZ     251.940952
# WBA    251.940952
# WMT    251.940952
# dtype: float64

# %%
ann_mean = returns.mean() * td_year
ann_mean
# Out:
# AAPL    0.487898
# AMGN    0.102032
# AXP     0.176384
# BA     -0.268409
# CAT     0.192152
# CRM     0.172310
# CSCO    0.012344
# CVX    -0.069611
# DIS     0.181280
# DOW     0.100777
# GS      0.270947
# HD      0.232426
# HON     0.140343
# IBM     0.019146
# INTC    0.026919
# JNJ     0.073077
# JPM     0.167107
# KO      0.073529
# MCD     0.094021
# MMM    -0.024385
# MRK    -0.003875
# MSFT    0.377857
# NKE     0.249705
# PG      0.133642
# TRV     0.050155
# UNH     0.206344
# V       0.195941
# VZ     -0.008523
# WBA    -0.106357
# WMT     0.145034
# dtype: float64

# %%
ann_std = returns.std() * np.sqrt(td_year)
ann_std
# Out:
# AAPL   0.360582
# AMGN   0.294037
# AXP    0.443248
# BA     0.623866
# CAT    0.351215
# CRM    0.392754
# CSCO   0.325475
# CVX    0.438856
# DIS    0.366696
# DOW    0.479802
# GS     0.385646
# HD     0.325795
# HON    0.327675
# IBM    0.315545
# INTC   0.420905
# JNJ    0.233780
# JPM    0.387311
# KO     0.256101
# MCD    0.288300
# MMM    0.306641
# MRK    0.251596
# MSFT   0.325851
# NKE    0.334367
# PG     0.245080
# TRV    0.358514
# UNH    0.360969
# V      0.315747
# VZ     0.200402
# WBA    0.382906
# WMT    0.236918
# dtype: float64

# %%
summary = pd.DataFrame(data = {"ann_mean": ann_mean, "ann_std": ann_std})
summary
# Out:
#       ann_mean  ann_std
# AAPL  0.487898 0.360582
# AMGN  0.102032 0.294037
# AXP   0.176384 0.443248
# BA   -0.268409 0.623866
# CAT   0.192152 0.351215
# CRM   0.172310 0.392754
# CSCO  0.012344 0.325475
# CVX  -0.069611 0.438856
# DIS   0.181280 0.366696
# DOW   0.100777 0.479802
# GS    0.270947 0.385646
# HD    0.232426 0.325795
# HON   0.140343 0.327675
# IBM   0.019146 0.315545
# INTC  0.026919 0.420905
# JNJ   0.073077 0.233780
# JPM   0.167107 0.387311
# KO    0.073529 0.256101
# MCD   0.094021 0.288300
# MMM  -0.024385 0.306641
# MRK  -0.003875 0.251596
# MSFT  0.377857 0.325851
# NKE   0.249705 0.334367
# PG    0.133642 0.245080
# TRV   0.050155 0.358514
# UNH   0.206344 0.360969
# V     0.195941 0.315747
# VZ   -0.008523 0.200402
# WBA  -0.106357 0.382906
# WMT   0.145034 0.236918

# %%
rf = 0 # simplification, don't use this assumption for portfolio management!

# %%
summary["Sharpe"] = (summary.ann_mean - rf) / summary.ann_std
summary
# Out:
#       ann_mean  ann_std    Sharpe
# AAPL  0.487898 0.360582  1.353085
# AMGN  0.102032 0.294037  0.347005
# AXP   0.176384 0.443248  0.397935
# BA   -0.268409 0.623866 -0.430234
# CAT   0.192152 0.351215  0.547106
# CRM   0.172310 0.392754  0.438722
# CSCO  0.012344 0.325475  0.037925
# CVX  -0.069611 0.438856 -0.158618
# DIS   0.181280 0.366696  0.494360
# DOW   0.100777 0.479802  0.210039
# GS    0.270947 0.385646  0.702580
# HD    0.232426 0.325795  0.713411
# HON   0.140343 0.327675  0.428301
# IBM   0.019146 0.315545  0.060675
# INTC  0.026919 0.420905  0.063956
# JNJ   0.073077 0.233780  0.312588
# JPM   0.167107 0.387311  0.431454
# KO    0.073529 0.256101  0.287110
# MCD   0.094021 0.288300  0.326122
# MMM  -0.024385 0.306641 -0.079524
# MRK  -0.003875 0.251596 -0.015403
# MSFT  0.377857 0.325851  1.159601
# NKE   0.249705 0.334367  0.746798
# PG    0.133642 0.245080  0.545298
# TRV   0.050155 0.358514  0.139895
# UNH   0.206344 0.360969  0.571638
# V     0.195941 0.315747  0.620562
# VZ   -0.008523 0.200402 -0.042531
# WBA  -0.106357 0.382906 -0.277764
# WMT   0.145034 0.236918  0.612168

# %%
summary.sort_values(by = "Sharpe", ascending=False)
# Out:
#       ann_mean  ann_std    Sharpe
# AAPL  0.487898 0.360582  1.353085
# MSFT  0.377857 0.325851  1.159601
# NKE   0.249705 0.334367  0.746798
# HD    0.232426 0.325795  0.713411
# GS    0.270947 0.385646  0.702580
# V     0.195941 0.315747  0.620562
# WMT   0.145034 0.236918  0.612168
# UNH   0.206344 0.360969  0.571638
# CAT   0.192152 0.351215  0.547106
# PG    0.133642 0.245080  0.545298
# DIS   0.181280 0.366696  0.494360
# CRM   0.172310 0.392754  0.438722
# JPM   0.167107 0.387311  0.431454
# HON   0.140343 0.327675  0.428301
# AXP   0.176384 0.443248  0.397935
# AMGN  0.102032 0.294037  0.347005
# MCD   0.094021 0.288300  0.326122
# JNJ   0.073077 0.233780  0.312588
# KO    0.073529 0.256101  0.287110
# DOW   0.100777 0.479802  0.210039
# TRV   0.050155 0.358514  0.139895
# INTC  0.026919 0.420905  0.063956
# IBM   0.019146 0.315545  0.060675
# CSCO  0.012344 0.325475  0.037925
# MRK  -0.003875 0.251596 -0.015403
# VZ   -0.008523 0.200402 -0.042531
# MMM  -0.024385 0.306641 -0.079524
# CVX  -0.069611 0.438856 -0.158618
# WBA  -0.106357 0.382906 -0.277764
# BA   -0.268409 0.623866 -0.430234
