# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format

start = "2014-10-01"
end = "2021-05-31"

symbols = ["BTC-USD"]

df = yf.download(symbols, start, end)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close       Volume
# Date
# 2014-10-01   387.4270   391.3790   380.7800   383.6150   383.6150     26229400
# 2014-10-02   383.9880   385.4970   372.9460   375.0720   375.0720     21777700
# 2014-10-03   375.1810   377.6950   357.8590   359.5120   359.5120     30901200
# 2014-10-04   359.8920   364.4870   325.8860   328.8660   328.8660     47236500
# 2014-10-05   328.9160   341.8010   289.2960   320.5100   320.5100     83308096
# ...               ...        ...        ...        ...        ...          ...
# 2021-05-26 38392.6250 40782.0781 37905.8359 39294.1992 39294.1992  51346735160
# 2021-05-27 39316.8906 40379.6172 37247.9023 38436.9688 38436.9688  43210968721
# 2021-05-28 38507.0820 38856.9688 34779.0391 35697.6055 35697.6055  55200191952
# 2021-05-29 35684.1562 37234.5000 33693.9297 34616.0664 34616.0664  45231013335
# 2021-05-30 34607.4062 36400.6680 33520.7383 35678.1289 35678.1289  31646080921
#
# [2434 rows x 6 columns]

# %%
btc = df.Close.dropna().copy().to_frame()
btc
# Out:
#                 Close
# Date
# 2014-10-01   383.6150
# 2014-10-02   375.0720
# 2014-10-03   359.5120
# 2014-10-04   328.8660
# 2014-10-05   320.5100
# ...               ...
# 2021-05-26 39294.1992
# 2021-05-27 38436.9688
# 2021-05-28 35697.6055
# 2021-05-29 34616.0664
# 2021-05-30 35678.1289
#
# [2434 rows x 1 columns]

# %%
btc.plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
btc["Returns"] = btc.Close.pct_change(periods = 1)
btc
# Out:
#                 Close  Returns
# Date
# 2014-10-01   383.6150      NaN
# 2014-10-02   375.0720  -0.0223
# 2014-10-03   359.5120  -0.0415
# 2014-10-04   328.8660  -0.0852
# 2014-10-05   320.5100  -0.0254
# ...               ...      ...
# 2021-05-26 39294.1992   0.0232
# 2021-05-27 38436.9688  -0.0218
# 2021-05-28 35697.6055  -0.0713
# 2021-05-29 34616.0664  -0.0303
# 2021-05-30 35678.1289   0.0307
#
# [2434 rows x 2 columns]

# %%
mu = btc.Returns.mean() # arithmetic mean return -> Reward
mu
# Out:
# 0.0028223969726665736

# %%
sigma = btc.Returns.std() # standard deviation of returns -> Risk/Volatility
sigma
# Out:
# 0.039120524806292634

# %% [markdown]
# Does the rule "Higher Risk -> Higher Reward" hold? -> Yes
