# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format

start = "2015-01-02"
end = "2020-12-31"

symbols = ["GE", "BRK-A"]

df = yf.download(symbols, start, end)
df
# Out:
# [*********************100%***********************]  2 of 2 completed
#              Adj Close                Close                 High           \
#                  BRK-A       GE       BRK-A       GE       BRK-A       GE
# Date
# 2015-01-02 223600.0000 130.3897 223600.0000 150.4834 227470.0000 152.8854
# 2015-01-05 220980.0000 127.9963 220980.0000 147.7211 223595.0000 150.1832
# 2015-01-06 220450.0000 125.2386 220450.0000 144.5385 222870.0000 147.5410
# 2015-01-07 223480.0000 125.2907 223480.0000 144.5986 223536.0000 146.4601
# 2015-01-08 226680.0000 126.7996 226680.0000 146.3400 226949.0000 146.4001
# ...                ...      ...         ...      ...         ...      ...
# 2020-12-23 336700.0000  67.2564 336700.0000  67.8220 338533.0000  68.5714
# 2020-12-24 340262.0000  65.9559 340262.0000  66.5105 341000.0000  67.7596
# 2020-12-28 342601.0000  65.8940 342601.0000  66.4481 345250.0000  67.3224
# 2020-12-29 344820.0000  65.3985 344820.0000  65.9485 346677.0000  67.2600
# 2020-12-30 345095.0000  66.3275 345095.0000  66.8852 346111.0000  67.7596
#
#                    Low                 Open          Volume
#                  BRK-A       GE       BRK-A       GE  BRK-A        GE
# Date
# 2015-01-02 222735.0000 149.3425 227230.0000 152.1648    300   6814541
# 2015-01-05 220000.0000 147.2407 223595.0000 150.1832    500   6999789
# 2015-01-06 219266.0000 143.6978 221110.0000 146.8804    400  10617953
# 2015-01-07 220000.0000 143.9981 222500.0000 145.3792    400   7267786
# 2015-01-08 224000.0000 144.8988 226124.0000 146.0397    600   7198159
# ...                ...      ...         ...      ...    ...       ...
# 2020-12-23 336400.0000  66.3232 336400.0000  66.6979    400   9688283
# 2020-12-24 337000.0000  66.3232 337000.0000  67.7596    200   4811708
# 2020-12-28 341445.0000  66.0734 342000.0000  66.8228    500   8614197
# 2020-12-29 343975.0000  65.8236 345144.0000  66.5730    300   8492373
# 2020-12-30 343917.0000  65.8860 344410.0000  66.0734    200   8105688
#
# [1510 rows x 12 columns]

# %%
close = df.Close.copy()
close
# Out:
#                  BRK-A       GE
# Date
# 2015-01-02 223600.0000 150.4834
# 2015-01-05 220980.0000 147.7211
# 2015-01-06 220450.0000 144.5385
# 2015-01-07 223480.0000 144.5986
# 2015-01-08 226680.0000 146.3400
# ...                ...      ...
# 2020-12-23 336700.0000  67.8220
# 2020-12-24 340262.0000  66.5105
# 2020-12-28 342601.0000  66.4481
# 2020-12-29 344820.0000  65.9485
# 2020-12-30 345095.0000  66.8852
#
# [1510 rows x 2 columns]

# %%
close.GE.dropna().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
norm = close.div(close.iloc[0])
norm
# Out:
#             BRK-A     GE
# Date
# 2015-01-02 1.0000 1.0000
# 2015-01-05 0.9883 0.9816
# 2015-01-06 0.9859 0.9605
# 2015-01-07 0.9995 0.9609
# 2015-01-08 1.0138 0.9725
# ...           ...    ...
# 2020-12-23 1.5058 0.4507
# 2020-12-24 1.5217 0.4420
# 2020-12-28 1.5322 0.4416
# 2020-12-29 1.5421 0.4382
# 2020-12-30 1.5434 0.4445
#
# [1510 rows x 2 columns]

# %%
norm.dropna().plot(figsize = (15, 8), fontsize = 13, logy = False)
plt.legend(fontsize = 13)
plt.show()

# %%
norm.GE[-1] # last value of GE (in the dataset)
# Out:
# 0.44446927017424315
