# %% [markdown]
# # 5. Calculus

# %% [markdown]
# ## E5.3

# %%
from sympy import *

# %%
x = symbols('x')
f = x**3 - 2*(x**2) + x
plot(f)

# %%
fp = 3*(x**2) - 4*x + 1
solve(fp, x)
# Out:
# [1/3, 1]

# %%
f.subs(x, nsimplify(1/3))
# Out:
# 4/27
