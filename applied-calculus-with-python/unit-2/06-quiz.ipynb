# %%
from sympy import *
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1

# %%
log(5) == ln(5)
# Out:
# True

# %% [markdown]
# ## 2

# %%
x1 = np.linspace(1, 100)
x1
# Out:
# array([  1.        ,   3.02040816,   5.04081633,   7.06122449,
#          9.08163265,  11.10204082,  13.12244898,  15.14285714,
#         17.16326531,  19.18367347,  21.20408163,  23.2244898 ,
#         25.24489796,  27.26530612,  29.28571429,  31.30612245,
#         33.32653061,  35.34693878,  37.36734694,  39.3877551 ,
#         41.40816327,  43.42857143,  45.44897959,  47.46938776,
#         49.48979592,  51.51020408,  53.53061224,  55.55102041,
#         57.57142857,  59.59183673,  61.6122449 ,  63.63265306,
#         65.65306122,  67.67346939,  69.69387755,  71.71428571,
#         73.73469388,  75.75510204,  77.7755102 ,  79.79591837,
#         81.81632653,  83.83673469,  85.85714286,  87.87755102,
#         89.89795918,  91.91836735,  93.93877551,  95.95918367,
#         97.97959184, 100.        ])

# %%
y1 = np.log10(x1)
y1
# Out:
# array([0.        , 0.48006564, 0.70250087, 0.84888002, 0.95816393,
#        1.04540282, 1.11801489, 1.18020783, 1.23459992, 1.28293177,
#        1.32641947, 1.36594618, 1.40217362, 1.43561038, 1.46665582,
#        1.49562928, 1.5227901 , 1.54835181, 1.57249226, 1.59536123,
#        1.61708597, 1.63777554, 1.65752414, 1.67641363, 1.69451566,
#        1.71189327, 1.72860221, 1.74469204, 1.76020701, 1.77518677,
#        1.78966703, 1.80368003, 1.81725498, 1.83041844, 1.84319463,
#        1.85560568, 1.86767188, 1.87941189, 1.89084287, 1.90198068,
#        1.91283998, 1.92343435, 1.93377643, 1.94387795, 1.95374983,
#        1.9634023 , 1.97284489, 1.98208654, 1.99113563, 2.        ])

# %%
plt.plot(x1, y1)

# %%
y2 = np.emath.logn(0.9, x1)
y2
# Out:
# array([ -0.        , -10.49152017, -15.35269668, -18.55171707,
#        -20.94004543, -22.84659423, -24.43348355, -25.79266937,
#        -26.9813729 , -28.03763401, -28.98802909, -29.85185956,
#        -30.64358649, -31.37432496, -32.05280279, -32.68599876,
#        -33.27958081, -33.83821509, -34.36578897, -34.86557522,
#        -35.34035515, -35.7925123 , -36.22410488, -36.63692239,
#        -37.03253046, -37.4123067 , -37.77746964, -38.12910235,
#        -38.46817176, -38.79554472, -39.11200136, -39.41824625,
#        -39.7149179 , -40.00259672, -40.2818119 , -40.55304726,
#        -40.81674626, -41.0733164 , -41.32313301, -41.56654253,
#        -41.8038654 , -42.03539861, -42.26141793, -42.48217989,
#        -42.69792353, -42.90887192, -43.11523361, -43.31720382,
#        -43.51496556, -43.70869065])

# %%
plt.plot(x1, y2)

# %%
log(1)
# Out:
# 0

# %% [markdown]
# ## 3

# %%
(1/2)*ln(exp(2/5))
# Out:
# 0.200000000000000

# %% [markdown]
# ## 4

# %%
x, y, z = symbols('x y z', positive=True)

f4 = 2*ln(x) - ln(y+1) + 3*ln(z)
f4
# Out:
# 2*log(x) + 3*log(z) - log(y + 1)

# %%
simplify(f4)
# Out:
# log(x**2*z**3/(y + 1))

# %% [markdown]
# ## 5

# %%
x, y = symbols('x y', positive=True)

f5 = exp(2*ln(x) - ln(2*y))
f5
# Out:
# x**2/(2*y)

# %%
simplify(f5)
# Out:
# x**2/(2*y)

# %% [markdown]
# ## 6

# %%
q = symbols('q')

eq = Eq(exp(2*q**2), exp(3*q + 2), domain=S.Reals)
eq
# Out:
# Eq(exp(2*q**2), exp(3*q + 2))

# %%
solveset(eq)
# Out:
# {-1/2, 2}

# %% [markdown]
# ## 7

# %%
x = symbols('x')

eq = Eq(2*ln(x) - ln(2*x), 0)
eq
# Out:
# Eq(2*log(x) - log(2*x), 0)

# %%
solveset(eq, domain=S.Reals)
# Out:
# {2}

# %% [markdown]
# ## 8

# %%
k = symbols('k')

eq = Eq(2**(-12*k), 8)
eq
# Out:
# Eq(2**(-12*k), 8)

# %%
solveset(eq, domain=S.Reals).evalf()
# Out:
# {-0.25}

# %% [markdown]
# ## 9

# %%
t = symbols('t')

pt = 135120*exp(0.325*t)
pt
# Out:
# 135120*exp(0.325*t)

# %%
pt.subs(t, 20).evalf()
# Out:
# 89873937.4569542

# %% [markdown]
# ## 10

# %%
t = symbols('t')

eq = Eq(720*exp(0.03*t), 1400)
eq
# Out:
# Eq(720*exp(0.03*t), 1400)

# %%
solveset(eq, domain=S.Reals).evalf()
# Out:
# {22.1658767864416}
